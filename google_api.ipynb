# %%
import googlemaps
import pandas as pd

gmaps = googlemaps.Client(key='AIzaSyDlLnjQ9ZZYA8huSpqk1J5RPpWYo33Ntac')

# %%
cities= ["臺北市","新北市","桃園市","臺中市","臺南市","高雄市","基隆市","新竹市","嘉義市","新竹縣",
        "苗栗縣","彰化縣","南投縣","雲林縣","嘉義縣","屏東縣","宜蘭縣","花蓮縣","臺東縣","澎湖縣"]

# %%
geocode_result = gmaps.geocode("臺北市")
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Taipei',
#     'short_name': 'Taipei',
#     'types': ['colloquial_area', 'locality', 'political']},
#    {'long_name': 'Taiwan',
#     'short_name': 'TW',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Taipei, Taiwan',
#   'geometry': {'bounds': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}},
#    'location': {'lat': 25.0329694, 'lng': 121.5654177},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}}},
#   'place_id': 'ChIJmQrivHKsQjQR4MIK3c41aj8',
#   'types': ['colloquial_area', 'locality', 'political']}]

# %%
ids = []
for city in cities:
    # Geocoding an address
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    print("以"+city+"為中心半徑25000公尺的餐廳店家數量: "+str(len(gmaps.places_radar(keyword="寵物", 
                                                                      location=loc, radius=25000)['results'])))
    for place in gmaps.places_radar(keyword="餐廳", location=loc, radius=25000)['results']:
        ids.append(place['place_id'])
# Out:
# 以臺北市為中心半徑25000公尺的餐廳店家數量: 198
# 以新北市為中心半徑25000公尺的餐廳店家數量: 199
# 以桃園市為中心半徑25000公尺的餐廳店家數量: 193
# 以臺中市為中心半徑25000公尺的餐廳店家數量: 199
# 以臺南市為中心半徑25000公尺的餐廳店家數量: 198
# 以高雄市為中心半徑25000公尺的餐廳店家數量: 198
# 以基隆市為中心半徑25000公尺的餐廳店家數量: 185
# 以新竹市為中心半徑25000公尺的餐廳店家數量: 154
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
geocode_result = gmaps.geocode("捷運行天宮站")
loc = geocode_result[0]['geometry']['location']
geocode_result[0]['geometry']['location']
# Out:
# {'lat': 25.059717, 'lng': 121.533184}

# %%
ids = []
for place in gmaps.places_radar(keyword="餐廳", location=loc, radius=250)['results']:
    ids.append(place['place_id'])

# %%
ids
# Out:
# ['ChIJ5VoKzVipQjQRoIA0nVqC5L0',
#  'ChIJS-zNIF-pQjQR1vU1UjOlTM4',
#  'ChIJmRp8AeKrQjQRPrffr5IK_Ng',
#  'ChIJbR3m3l6pQjQRb7ZJrthhjAk',
#  'ChIJzzNFLVmpQjQR-vuhAtSqMkQ',
#  'ChIJEWgia1-pQjQRKAYzmyHz2QU',
#  'ChIJ-4RzGVmpQjQRJyaSXcMYgs0',
#  'ChIJfSQXtFepQjQRyP_FJSK0MwI',
#  'ChIJGeUSyV6pQjQR3ChjSq2Pzmc',
#  'ChIJcX8q7lupQjQRX9tnvR00qWE',
#  'ChIJiyHLEmOpQjQRamce9LWflok',
#  'ChIJCXiVb1-pQjQRySm5xdZ5kMU',
#  'ChIJ929c3lipQjQRav5ojgr7JWI',
#  'ChIJKRaPzl2pQjQR5SjG89Umehw',
#  'ChIJY7eEPVypQjQRqaV7IrEMKZc',
#  'ChIJ_ewBSVmpQjQRmdUnMSiJeC8',
#  'ChIJzUMT51ipQjQRtY7RA3-1dy0',
#  'ChIJFVY0MFmpQjQRcac-57uoQPs',
#  'ChIJ5bnsK1-pQjQRgNiShNpyXnU',
#  'ChIJx350ClypQjQRNc0Y1dwqV5U',
#  'ChIJ92nST1mpQjQR2jP6NYPifQg',
#  'ChIJMTpyPV-pQjQRl1Vg4e0pKpY',
#  'ChIJz3sj316pQjQRSoAA8hH2_5s',
#  'ChIJxXKO1GmpQjQRi-ksaGAFSvg',
#  'ChIJPSMSLl-pQjQRRX7FcWQgCIk',
#  'ChIJr49-0l6pQjQRBT4bdSdJLfc',
#  'ChIJu_3mx16pQjQRsVLxcsLiCVI',
#  'ChIJJwVz116pQjQRFjYsnOaZJaU',
#  'ChIJ_____16pQjQRELvKS6kHnNw',
# ...

# %%
stores_info = []
# 去除重複id
ids = list(set(ids)) 
for id in ids:
    stores_info.append(gmaps.place(place_id=id, language='zh-TW')['result'])

# %%
output = pd.DataFrame.from_dict(stores_info)

# %%
output
# Out:
#                                    address_components  \
# 0   [{'long_name': '7', 'short_name': '7', 'types'...
# 1   [{'long_name': '178', 'short_name': '178', 'ty...
# 2   [{'long_name': '2樓', 'short_name': '2樓', 'type...
# 3   [{'long_name': 'B1', 'short_name': 'B1', 'type...
# 4   [{'long_name': '274', 'short_name': '274', 'ty...
# 5   [{'long_name': '30號', 'short_name': '30號', 'ty...
# 6   [{'long_name': '台灣', 'short_name': 'TW', 'type...
# 7   [{'long_name': '台灣', 'short_name': 'TW', 'type...
# 8   [{'long_name': '224', 'short_name': '224', 'ty...
# 9   [{'long_name': '270號', 'short_name': '270號', '...
# 10  [{'long_name': '306', 'short_name': '306', 'ty...
# 11  [{'long_name': '22號', 'short_name': '22號', 'ty...
# 12  [{'long_name': '125-4', 'short_name': '125-4',...
# 13  [{'long_name': '96', 'short_name': '96', 'type...
# 14  [{'long_name': '8', 'short_name': '8', 'types'...
# 15  [{'long_name': '4號', 'short_name': '4號', 'type...
# ...
